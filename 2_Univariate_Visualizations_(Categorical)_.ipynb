# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/DATA-VISUALIZATION-/blob/main/2_Univariate_Visualizations_(Categorical)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/AB_NYC_2019 (2).csv")

# %%
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  19-10-2018               0.21
# 1    225               1                 45  21-05-2019               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# # Categorical

# %% [markdown]
# # Bar Graph

# %%
sns.countplot( x=df["room_type"])
# Out:
# <Axes: xlabel='room_type', ylabel='count'>

# %%
sns.countplot(data=df, x= "neighbourhood_group")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(data = df, x ="neighbourhood_group" , hue = "room_type")
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# # Pie Chart

# %%
df["room_type"].value_counts().plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df["availability_365"].value_counts().head(10).plot(kind ="bar")
# Out:
# <Axes: xlabel='availability_365'>

# %%
df2 = sns.load_dataset("titanic")

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(x = df2["survived"])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x = df2["embark_town"])
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %%
df2["class"].value_counts().plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x = df2["alone"])
# Out:
# <Axes: xlabel='alone', ylabel='count'>
