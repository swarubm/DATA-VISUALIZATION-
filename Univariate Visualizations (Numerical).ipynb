# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/DATA-VISUALIZATION-/blob/main/Univariate%20Visualizations%20(Numerical).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("/content/AB_NYC_2019 (2).csv")

# %%
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  19-10-2018               0.21
# 1    225               1                 45  21-05-2019               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# # Histogram

# %%
sns.histplot(df["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(df[df["price"]<500]["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(df[df["number_of_reviews"]<100]["number_of_reviews"])
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='Count'>

# %% [markdown]
# # Distplot

# %%
sns.distplot(df["price"])
# Out:
# /tmp/ipython-input-50337492.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df["price"].value_counts(bins = 20)
# Out:
# (-10.001, 500.0]     47862
# (500.0, 1000.0]        805
# (1000.0, 1500.0]       100
# (1500.0, 2000.0]        53
# (2500.0, 3000.0]        21
# (2000.0, 2500.0]        20
# (3500.0, 4000.0]        11
# (4000.0, 4500.0]         6
# (4500.0, 5000.0]         6
# (9500.0, 10000.0]        6
# (6000.0, 6500.0]         4
# (3000.0, 3500.0]         2
# (5500.0, 6000.0]         2
# (5000.0, 5500.0]         2
# (7500.0, 8000.0]         2
# (7000.0, 7500.0]         2
# (6500.0, 7000.0]         1
# (8000.0, 8500.0]         1
# (8500.0, 9000.0]         0
# (9000.0, 9500.0]         0
# Name: count, dtype: int64

# %%
sns.boxplot(df[df["price"]<500]["price"])
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(df[df["reviews_per_month"]<10]["reviews_per_month"])
# Out:
# <Axes: ylabel='reviews_per_month'>

# %%
df2 = sns.load_dataset("titanic")

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2[df2["fare"]==0]
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 413         0       2  male   NaN      0      0   0.0        S  Second  man
# 466         0       2  male   NaN      0      0   0.0        S  Second  man
# 481         0       2  male   NaN      0      0   0.0        S  Second  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 633         0       1  male   NaN      0      0   0.0        S   First  man
# 674         0       2  male   NaN      0      0   0.0        S  Second  man
# ...

# %%
sns.distplot(df2["age"])
# Out:
# /tmp/ipython-input-49255041.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["age"])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df2["fare"])
# Out:
# /tmp/ipython-input-3524834500.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["fare"])
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.boxplot(df2["age"])
# Out:
# <Axes: ylabel='age'>

# %%
sns.violinplot(df2["age"])
# Out:
# <Axes: ylabel='age'>
