# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/DATA-VISUALIZATION-/blob/main/5_Bivariate_Visualizations_(Categorical).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x = "sex", y= "age",hue = "survived" ,data = df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x="class", y= "age",hue = "sex", data = df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
x = pd.crosstab(df["class"],df["survived"])

# %%
x
# Out:
# survived    0    1
# class
# First      80  136
# Second     97   87
# Third     372  119

# %%
sns.heatmap(x,annot= True, fmt = ".1f")
# Out:
# <Axes: xlabel='survived', ylabel='class'>

# %%
df2 = sns.load_dataset("iris")
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df2.head(10).plot(kind = "bar")
# Out:
# <Axes: >

# %%
df2.head(10).plot(kind = "bar", stacked = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df2)
